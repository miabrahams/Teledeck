# %%
from telethon import TelegramClient
import telethon
from telethon import functions, types, utils
from telethon.tl import types as tltypes
from dotenv import load_dotenv
import os
from pprint import pprint


load_dotenv()  # take environment variables from .env.
api_id = os.environ['TG_API_ID']
api_hash = os.environ['TG_API_HASH']
phone = os.environ['TG_PHONE']
username = 'Hex'
client = TelegramClient(username, api_id, api_hash)

# %%
async def main():
    # Getting information about yourself
    me = await client.get_me()

    # "me" is a user object. You can pretty-print
    # any Telegram object with the "stringify" method:
    print(me.stringify())

    # When you print something, you see a representation of it.
    # You can access all attributes of Telegram objects with
    # the dot operator. For example, to get the username:
    username = me.username
    print(username)
    print(me.phone)

    # You can print all the dialogs/conversations that you are part of:
    # async for dialog in client.iter_dialogs():
    #     print(dialog.name, 'has ID', dialog.id)

    # You can send messages to yourself...
    await client.send_message('me', f'Hello, {username}!')
    # ...to some chat ID
    # await client.send_message(-100123456, 'Hello, group!')
    # ...to your contacts
    # await client.send_message('+34600123123', 'Hello, friend!')
    # ...or even to any username
    # await client.send_message('username', 'Testing Telethon!')

    # You can, of course, use markdown in your messages:
    message = await client.send_message(
        'me',
        'This message has **bold**, `code`, __italics__ and '
        'a [nice website](https://example.com)!',
        link_preview=False
    )

    # Sending a message returns the sent message object, which you can use
    print(message.raw_text)

    # You can reply to messages directly if you have a message object
    await message.reply('Cool!')

    # Or send files, songs, documents, albums...
    # await client.send_file('me', '/home/me/Pictures/holidays.jpg')

    # You can print the message history of any chat:
    async for message in client.iter_messages('me', limit=10):
        print(message.id, message.text)

        # You can download media from messages, too!
        # The method will return the path where the file was saved.
        """
        if message.photo:
            path = await message.download_media()
            print('File saved to', path)  # printed after download is done
        """

async with client:
    await main()

# %%
await client.connect()
# Out:
# Server closed the connection: [Errno 54] Connection reset by peer
# Server sent a very old message with ID 7391406519235818497, ignoring (see FAQ for details)
# Server sent a very old message with ID 7391406832130988033, ignoring (see FAQ for details)
# Server sent a very old message with ID 7391406849078254593, ignoring (see FAQ for details)
# Server sent a very old message with ID 7391406887575913485, ignoring (see FAQ for details)
# Server sent a very old message with ID 7391406887575913489, ignoring (see FAQ for details)
# Server sent a very old message with ID 7391406887575913493, ignoring (see FAQ for details)
# Server sent a very old message with ID 7391406887575913497, ignoring (see FAQ for details)
# Server sent a very old message with ID 7391406887575913481, ignoring (see FAQ for details)
# Server sent a very old message with ID 7391406887575980033, ignoring (see FAQ for details)
# Server sent a very old message with ID 7391406900083571713, ignoring (see FAQ for details)
# ...

# %%
dialogs = await client.get_dialogs()

dialog_by_id = {}
for d in dialogs:
    real_id, peer_type = utils.resolve_id(d.id)
    print(real_id, peer_type)
    dialog_by_id[real_id] = d

# client.get_channels(dialog_by_id.keys())
# Out:
# 247762012 <class 'telethon.tl.types.PeerUser'>
# 1265830460 <class 'telethon.tl.types.PeerChannel'>
# 1528143423 <class 'telethon.tl.types.PeerChannel'>
# 1150680064 <class 'telethon.tl.types.PeerUser'>
# 1160487164 <class 'telethon.tl.types.PeerChannel'>
# 1103072576 <class 'telethon.tl.types.PeerChannel'>
# 1130198287 <class 'telethon.tl.types.PeerChannel'>
# 1142285439 <class 'telethon.tl.types.PeerChannel'>
# 1259930814 <class 'telethon.tl.types.PeerChannel'>
# 1194004105 <class 'telethon.tl.types.PeerChannel'>
# 5694771567 <class 'telethon.tl.types.PeerUser'>
# 1125391613 <class 'telethon.tl.types.PeerChannel'>
# 1357160510 <class 'telethon.tl.types.PeerChannel'>
# 1462489278 <class 'telethon.tl.types.PeerChannel'>
# 1771838474 <class 'telethon.tl.types.PeerChannel'>
# 1321997320 <class 'telethon.tl.types.PeerChannel'>
# 1214855655 <class 'telethon.tl.types.PeerChannel'>
# 1127924025 <class 'telethon.tl.types.PeerChannel'>
# 1172849990 <class 'telethon.tl.types.PeerChannel'>
# ...

# %%
filtered = filter(lambda dialog: dialog.name.find('Jeremy') > -1, dialogs)
f: telethon.tl.custom.dialog.Dialog = next(filtered)

# %%
last_messages = await client.get_messages(f, limit=20)
[print(m) for m in last_messages]

# await client.delete_messages(f, [127462], revoke=True)

# %%
chatFolders: tltypes.messages.DialogFilters = await client(functions.messages.GetDialogFiltersRequest())
print(chatFolders.stringify())

# %%
mediaFolder = None
for folder in chatFolders.filters:
    if not hasattr(folder, 'title'):
        continue
    if folder.title == 'MediaView':
        print(folder)
        mediaFolder = folder
        break
# Out:
# DialogFilter(id=48, title='MediaView', pinned_peers=[], include_peers=[InputPeerChannel(channel_id=1853857944, access_hash=6312540377902597213), InputPeerChannel(channel_id=1209919139, access_hash=-1776413402268666983), InputPeerChannel(channel_id=1426223303, access_hash=-1401347112577188138), InputPeerChannel(channel_id=1160487164, access_hash=-1247061625643424232), InputPeerChannel(channel_id=1194004105, access_hash=-5754630827738961831), InputPeerChannel(channel_id=1419113824, access_hash=-1258012889288736836), InputPeerChannel(channel_id=1092325450, access_hash=-8504595689817158984), InputPeerChannel(channel_id=1344946756, access_hash=135314353449045199), InputPeerChannel(channel_id=1227354457, access_hash=7130293134788703512), InputPeerChannel(channel_id=1801177686, access_hash=-1740352403772049484), InputPeerChannel(channel_id=1692224524, access_hash=-2084092216638460618), InputPeerChannel(channel_id=1816668235, access_hash=7189094654017076740), InputPeerChannel(channel_id=1214
# ...

# %%
target_channels = [dialog_by_id[peer.channel_id] for peer in mediaFolder.include_peers]
# target_channels = [client.get_entity(peer) for peer in mediaFolder.include_peers]
# await client.get_entity(peer)

# %%
target_channels = [dialog_by_id[peer.channel_id] for peer in mediaFolder.include_peers]
for channel in target_channels:
    print(channel)
# Out:
# Dialog(name='Vore: Snack➡️Scat', date=datetime.datetime(2024, 7, 12, 23, 45, 3, tzinfo=datetime.timezone.utc), draft=<telethon.tl.custom.draft.Draft object at 0x11876e0d0>, message=Message(id=1301, peer_id=PeerChannel(channel_id=1853857944), date=datetime.datetime(2024, 7, 12, 23, 45, 3, tzinfo=datetime.timezone.utc), message='', out=False, mentioned=False, media_unread=False, silent=False, post=True, from_scheduled=False, legacy=False, edit_hide=True, pinned=False, noforwards=False, invert_media=False, offline=False, from_id=None, from_boosts_applied=None, saved_peer_id=None, fwd_from=None, via_bot_id=None, via_business_bot_id=None, reply_to=None, media=MessageMediaPhoto(spoiler=False, photo=Photo(id=4940861057002482853, access_hash=-6191075697306445753, file_reference=b'\x02n\x7f\xa0\x98\x00\x00\x05\x15f\x93t\x1a\xb3\xd3\xbc\xa1\x1d\x8b\xf12B\xb0\xc3\x8c;\x87\x12\x1d', date=datetime.datetime(2024, 7, 12, 23, 44, 52, tzinfo=datetime.timezone.utc), sizes=[PhotoStrippedSize(type='i', 
# ...

# %%
# Test messages in the first two channels
"""
for channel_id in target_channels[0:2]:
    async for message in client.iter_messages(channel_id, limit=5):
        print(message.stringify())
"""

# Grab most recent post @ self to test twitter embed
test_message = None
async for message in client.iter_messages('me', limit=1):
    test_message = message

# %%
print(test_message.stringify())

# test_message.media = MessageMediaWebPage
print(test_message.document)
# Out:
# Message(
# 	id=127524,
# 	peer_id=PeerUser(
# 		user_id=1150680064
# 	),
# 	date=datetime.datetime(2024, 7, 14, 15, 5, 39, tzinfo=datetime.timezone.utc),
# 	message='https://vxtwitter.com/joostmaglev/status/1808765613067657336?s=46&t=evZG0KDb2ipOXg4Dp8hBpg',
# 	out=True,
# 	mentioned=False,
# 	media_unread=False,
# 	silent=False,
# 	post=False,
# 	from_scheduled=False,
# 	legacy=False,
# 	edit_hide=False,
# 	pinned=False,
# 	noforwards=False,
# 	invert_media=False,
# 	offline=False,
# 	from_id=None,
# 	from_boosts_applied=None,
# 	saved_peer_id=PeerUser(
# 		user_id=1150680064
# 	),
# 	fwd_from=None,
# 	via_bot_id=None,
# 	via_business_bot_id=None,
# 	reply_to=None,
# 	media=MessageMediaWebPage(
# 		webpage=WebPage(
# 			id=703655831509956328,
# 			url='https://vxtwitter.com/joostmaglev/status/1808765613067657336?s=46&t=evZG0KDb2ipOXg4Dp8hBpg',
# 			display_url='vxtwitter.com/joostmaglev/status/1808765613067657336?s=46&t=evZG0KDb2ipOXg4Dp8hBpg',
# 			hash=0,
# ...

# %%
async def collect_posts(client, target_channels, limit=5):
    post_collection = []

    for channel in target_channels:
        async for message in client.iter_messages(channel, limit=limit):
            post_collection.append(message)
    return post_collection


posts = await collect_posts(client, target_channels, limit=5)

# %%
# Custom download
DOWNLOAD_PATH = os.path.join(os.getcwd(), 'downloads')
def callback(current, total):
    print('Downloaded', current, 'out of', total,
          'bytes: {:.2%}'.format(current / total))

async def download(client, messsage):
    return await client.download_media(message, DOWNLOAD_PATH, progress_callback=callback)


async def other_media(client, message):
    path = await download(client, message)
    media_info = {
        'type': 'unknown',
        'id': message.id,
        'date': message.date,
        'path': path,
        'channel': channel.title
    }
    if message.document.mime_type == 'image/webp':
        print(f"Has webp: {message.id}")
        media_info.update({
            'type': 'webp',
            'file': message.file
        })
    elif message.document.mime_type == 'image/jpeg':
        print(f"Has jpeg: {message.id}")
        media_info.update({
            'type': 'jpeg',
            'file': message.file
        })
    elif message.document.mime_type == 'image/png':
        print(f"Has png: {message.id}")
        media_info.update({
            'type': 'png',
            'file': message.file
        })
    else:
        print("Unknown media type: ", message.document.mime_type)
    return media_info



async def collect_media(client, message_collection):

    media_collection = []
    # message.download_media(*args, **kwargs)
    # https://docs.telethon.dev/en/stable/modules/client.html#telethon.client.downloads.DownloadMethods.download_media
    for message in message_collection:
        media_info = None
        if message.photo:
            print(f"Has photo: {message.id}")
            path = await client.download_media(message, DOWNLOAD_PATH)
            media_info = {
                'type': 'photo',
                'file': message.photo,
                'path': path,
                'id': message.id,
                'date': message.date,
                'channel': channel.title,
            }
        elif message.document:
            if message.gif:
                print(f"Has gif: {message.id}")
                path = await download(client, message)
                media_info = {
                    'type': 'gif',
                    'file': message.gif,
                    # 'path': path,
                    'id': message.id,
                    'date': message.date,
                    'channel': channel.title,
                }
            elif message.video:
                print(f"Has video: {message.id}")
                path = await download(client, message)
                media_info = {
                    'type': 'video',
                    'file': message.video,
                    'id': message.id,
                    'date': message.date,
                    'channel': channel.title
                }
            else:
                media_info = other_media(client, message)
        elif message.web_preview:
            print(f"Has web preview: {message.id}")
            print(message.web_preview)
            media_info = {
                'type': 'web_preview',
                'preview_item': message.web_preview,
                'url': message.web_preview.url,
                'id': message.id,
                'date': message.date,
                'channel': channel.title
            }
        if media_info:
            media_collection.append(media_info)
        else:
            print(f"No media found: {message.id}")
            # print(message)
            media_collection.append({})
    return media_collection

# print(len(posts))
media = await collect_media(client, posts)

# Todo: Scrape text for fun snippets & stories. Feed into an LLM maybe?
# Out:
#   Cell In[66], line 53
#     path =
#           ^
# SyntaxError: invalid syntax

# %%
await client.disconnect()
