# %%
from telethon import TelegramClient
import telethon
from telethon import functions, utils
from telethon.tl.types import Message, Channel
from telethon.tl.types.messages import DialogFilters
from telethon.tl.custom.file import File
from tqdm import tqdm
from dotenv import load_dotenv
from typing import List, Dict, Any
import os
import asyncio
import sqlite3
import json
from datetime import date, datetime


load_dotenv()  # take environment variables from .env.
api_id = os.environ['TG_API_ID']
api_hash = os.environ['TG_API_HASH']
phone = os.environ['TG_PHONE']
username = 'Hex'


# Paths
MEDIA_PATH = './static/media/'
DB_PATH = './GOTTH/goth.db'

# Ensure media directory exists
os.makedirs(MEDIA_PATH, exist_ok=True)

def progress_callback(current: int, total: int) -> None:
    print(f'Downloaded {current} out of {total} bytes: {current / total:.2%}')

async def download_media(client, message: Message) -> str:
    return await client.download_media(message, MEDIA_PATH, progress_callback=progress_callback)

# %% [markdown]
# ## Experiments and scratch

# %%
async def main():
    # Getting information about yourself
    me = await client.get_me()

    # "me" is a user object. You can pretty-print
    # any Telegram object with the "stringify" method:
    print(me.stringify())

    # When you print something, you see a representation of it.
    # You can access all attributes of Telegram objects with
    # the dot operator. For example, to get the username:
    username = me.username
    print(username)
    print(me.phone)

    # You can print all the dialogs/conversations that you are part of:
    # async for dialog in client.iter_dialogs():
    #     print(dialog.name, 'has ID', dialog.id)

    # You can send messages to yourself...
    await client.send_message('me', f'Hello, {username}!')
    # ...to some chat ID
    # await client.send_message(-100123456, 'Hello, group!')
    # ...to your contacts
    # await client.send_message('+34600123123', 'Hello, friend!')
    # ...or even to any username
    # await client.send_message('username', 'Testing Telethon!')

    # You can, of course, use markdown in your messages:
    message = await client.send_message(
        'me',
        'This message has **bold**, `code`, __italics__ and '
        'a [nice website](https://example.com)!',
        link_preview=False
    )

    # Sending a message returns the sent message object, which you can use
    print(message.raw_text)

    # You can reply to messages directly if you have a message object
    await message.reply('Cool!')

    # Or send files, songs, documents, albums...
    # await client.send_file('me', '/home/me/Pictures/holidays.jpg')

    # You can print the message history of any chat:
    async for message in client.iter_messages('me', limit=10):
        print(message.id, message.text)

        # You can download media from messages, too!
        # The method will return the path where the file was saved.
        """
        if message.photo:
            path = await message.download_media()
            print('File saved to', path)  # printed after download is done
        """

async with client:
    await main()
# Out:
# User(
# 	id=1150680064,
# 	is_self=True,
# 	contact=False,
# 	mutual_contact=False,
# 	deleted=False,
# 	bot=False,
# 	bot_chat_history=False,
# 	bot_nochats=False,
# 	verified=False,
# 	restricted=False,
# 	min=False,
# 	bot_inline_geo=False,
# 	support=False,
# 	scam=False,
# 	apply_min_photo=True,
# 	fake=False,
# 	bot_attach_menu=False,
# 	premium=False,
# 	attach_menu_enabled=False,
# 	bot_can_edit=False,
# 	close_friend=False,
# 	stories_hidden=False,
# 	stories_unavailable=True,
# 	contact_require_premium=False,
# 	bot_business=False,
# 	access_hash=7442491767998803744,
# 	first_name='𝙃𝙀𝙓',
# 	last_name='🔌',
# 	username='technoyote',
# 	phone='19174773836',
# 	photo=UserProfilePhoto(
# 		photo_id=5143514218371329056,
# 		dc_id=1,
# 		has_video=False,
# 		personal=False,
# 		stripped_thumb=b'\x01\x08\x08S\x1b\x89\x11\x19\xb1\x9caOLQE\x14\x92*\xfa\x1f'
# 	),
# 	status=UserStatusOnline(
# 		expires=datetime.datetime(2024, 7, 15, 0, 48, 16, tzinfo=datetime.timezone.utc)
# 	),
# 	bot_info_version=None,
# 	restriction_reason=[
# 	],
# 	bot_inline_placeholder=None,
# 	lang_code=None,
# 	emoji_status=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None
# )
# technoyote
# 19174773836
# This message has bold, code, italics and a nice website!
# 127613 Cool!
# 127612 This message has **bold**, `code`, __italics__ and a [nice website](https://example.com/)!
# 127611 Hello, technoyote!
# 127610 Cool!
# 127609 This message has **bold**, `code`, __italics__ and a [nice website](https://example.com/)!
# 127608 Hello, technoyote!
# 127571 https://discord.com/invite/NngFZ7B
# 127556 *** 10 things
#
#
# List specific items of outstanding balance.
# Materialize understanding of who it is coming from.
#
#
# 1. Things I blame others for
# Not mentoring me enough at MIT
# Attacking and abandoning me in the furry fandom
# Rejecting me in job interviews
#
#
#
#
#
#
# 2. Things others blame me for
#
# What situations do I avoid from
#
# Being a recluse
# Being racist
# Being a dick
# Not working hard enough
#
# Being uninteresting
# Being stupid
# Being incompetent
#
#
#
#
# 3. Things I blame myself for
# Failing job interviews
# Not having enough energy
# Not being clever enough
# Not being creative enough
# Being emotionally volatile
# Being a recluse
# Not connecting with my brother
# 127524 https://vxtwitter.com/joostmaglev/status/1808765613067657336?s=46&t=evZG0KDb2ipOXg4Dp8hBpg
# 127522 https://x.com/fluentinfinance/status/1811967583446327428?s=46

# %%
client = TelegramClient(username, api_id, api_hash)
await client.connect()

# %%
dialogs = await client.get_dialogs()

dialog_by_id = {}
for d in dialogs:
    real_id, peer_type = utils.resolve_id(d.id)
    print(real_id, peer_type)
    dialog_by_id[real_id] = d

# client.get_channels(dialog_by_id.keys())
# Out:
# 247762012 <class 'telethon.tl.types.PeerUser'>
# 1265830460 <class 'telethon.tl.types.PeerChannel'>
# 1528143423 <class 'telethon.tl.types.PeerChannel'>
# 1150680064 <class 'telethon.tl.types.PeerUser'>
# 1206981154 <class 'telethon.tl.types.PeerChannel'>
# 1357160510 <class 'telethon.tl.types.PeerChannel'>
# 1771838474 <class 'telethon.tl.types.PeerChannel'>
# 1197643198 <class 'telethon.tl.types.PeerChannel'>
# 1252494604 <class 'telethon.tl.types.PeerChannel'>
# 1462489278 <class 'telethon.tl.types.PeerChannel'>
# 1227535643 <class 'telethon.tl.types.PeerChannel'>
# 1142285439 <class 'telethon.tl.types.PeerChannel'>
# 1206582385 <class 'telethon.tl.types.PeerChannel'>
# 1079449091 <class 'telethon.tl.types.PeerChannel'>
# 1426223303 <class 'telethon.tl.types.PeerChannel'>
# 5694771567 <class 'telethon.tl.types.PeerUser'>
# 111069226 <class 'telethon.tl.types.PeerUser'>
# 1259383341 <class 'telethon.tl.types.PeerChannel'>
# 1127924025 <class 'telethon.tl.types.PeerChannel'>
# 1160487164 <class 'telethon.tl.types.PeerChannel'>
# 1321997320 <class 'telethon.tl.types.PeerChannel'>
# 1172849990 <class 'telethon.tl.types.PeerChannel'>
# 1410314904 <class 'telethon.tl.types.PeerChannel'>
# 1051848570 <class 'telethon.tl.types.PeerChannel'>
# 1398805943 <class 'telethon.tl.types.PeerChannel'>
# 1397126529 <class 'telethon.tl.types.PeerChannel'>
# 1194004105 <class 'telethon.tl.types.PeerChannel'>
# 1816668235 <class 'telethon.tl.types.PeerChannel'>
# 1130198287 <class 'telethon.tl.types.PeerChannel'>
# 1259930814 <class 'telethon.tl.types.PeerChannel'>
# 76065323 <class 'telethon.tl.types.PeerUser'>
# 1103072576 <class 'telethon.tl.types.PeerChannel'>
# 1801177686 <class 'telethon.tl.types.PeerChannel'>
# 2022414023 <class 'telethon.tl.types.PeerChannel'>
# 1288431174 <class 'telethon.tl.types.PeerChannel'>
# 1125391613 <class 'telethon.tl.types.PeerChannel'>
# 1195713767 <class 'telethon.tl.types.PeerChannel'>
# 1558639234 <class 'telethon.tl.types.PeerChannel'>
# 1302639436 <class 'telethon.tl.types.PeerChannel'>
# 1680261262 <class 'telethon.tl.types.PeerChannel'>
# 1857847622 <class 'telethon.tl.types.PeerChannel'>
# 1091347989 <class 'telethon.tl.types.PeerChannel'>
# 1398668399 <class 'telethon.tl.types.PeerChannel'>
# 1589412318 <class 'telethon.tl.types.PeerChannel'>
# 1483716591 <class 'telethon.tl.types.PeerChannel'>
# 1256201605 <class 'telethon.tl.types.PeerChannel'>
# 1312841387 <class 'telethon.tl.types.PeerChannel'>
# 1125800041 <class 'telethon.tl.types.PeerChannel'>
# 1704304298 <class 'telethon.tl.types.PeerChannel'>
# 1181411205 <class 'telethon.tl.types.PeerChannel'>
# 1344946756 <class 'telethon.tl.types.PeerChannel'>
# 1424632808 <class 'telethon.tl.types.PeerChannel'>
# 1208752784 <class 'telethon.tl.types.PeerChannel'>
# 2003243100 <class 'telethon.tl.types.PeerChannel'>
# 1114909686 <class 'telethon.tl.types.PeerChannel'>
# 1853857944 <class 'telethon.tl.types.PeerChannel'>
# 1555963370 <class 'telethon.tl.types.PeerChannel'>
# 1455167081 <class 'telethon.tl.types.PeerChannel'>
# 1343458282 <class 'telethon.tl.types.PeerChannel'>
# 1858897842 <class 'telethon.tl.types.PeerChannel'>
# 1214855655 <class 'telethon.tl.types.PeerChannel'>
# 75848525 <class 'telethon.tl.types.PeerUser'>
# 2195639077 <class 'telethon.tl.types.PeerChannel'>
# 1234494257 <class 'telethon.tl.types.PeerChannel'>
# 777000 <class 'telethon.tl.types.PeerUser'>
# 1424981263 <class 'telethon.tl.types.PeerChannel'>
# 1469894855 <class 'telethon.tl.types.PeerChannel'>
# 1692224524 <class 'telethon.tl.types.PeerChannel'>
# 1195427653 <class 'telethon.tl.types.PeerChannel'>
# 1539142705 <class 'telethon.tl.types.PeerChannel'>
# 1407468739 <class 'telethon.tl.types.PeerChannel'>
# 1153080681 <class 'telethon.tl.types.PeerChannel'>
# 1557426322 <class 'telethon.tl.types.PeerChannel'>
# 1826739658 <class 'telethon.tl.types.PeerChannel'>
# 1841075053 <class 'telethon.tl.types.PeerChannel'>
# 1092325450 <class 'telethon.tl.types.PeerChannel'>
# 1321716884 <class 'telethon.tl.types.PeerChannel'>
# 1941293920 <class 'telethon.tl.types.PeerChannel'>
# 1255674377 <class 'telethon.tl.types.PeerChannel'>
# 1205923638 <class 'telethon.tl.types.PeerChannel'>
# 1338250115 <class 'telethon.tl.types.PeerChannel'>
# 1171628811 <class 'telethon.tl.types.PeerChannel'>
# 1224624669 <class 'telethon.tl.types.PeerChannel'>
# 1475867202 <class 'telethon.tl.types.PeerChannel'>
# 1264963029 <class 'telethon.tl.types.PeerChannel'>
# 1466638826 <class 'telethon.tl.types.PeerChannel'>
# 2105268713 <class 'telethon.tl.types.PeerChannel'>
# 486018153 <class 'telethon.tl.types.PeerUser'>
# 1209919139 <class 'telethon.tl.types.PeerChannel'>
# 2079596559 <class 'telethon.tl.types.PeerChannel'>
# 1200463433 <class 'telethon.tl.types.PeerChannel'>
# 34676904 <class 'telethon.tl.types.PeerUser'>
# 1227354457 <class 'telethon.tl.types.PeerChannel'>
# 644968243 <class 'telethon.tl.types.PeerUser'>
# 1839717144 <class 'telethon.tl.types.PeerChannel'>
# 1347350490 <class 'telethon.tl.types.PeerChannel'>
# 1379060277 <class 'telethon.tl.types.PeerChannel'>
# 1955017308 <class 'telethon.tl.types.PeerChannel'>
# 1754989111 <class 'telethon.tl.types.PeerChannel'>
# 2022234322 <class 'telethon.tl.types.PeerChannel'>
# 329601819 <class 'telethon.tl.types.PeerUser'>
# 1457896735 <class 'telethon.tl.types.PeerChannel'>
# 1433785745 <class 'telethon.tl.types.PeerUser'>
# 1330169550 <class 'telethon.tl.types.PeerChannel'>
# 1832454123 <class 'telethon.tl.types.PeerChannel'>
# 1303545899 <class 'telethon.tl.types.PeerChannel'>
# 220534933 <class 'telethon.tl.types.PeerUser'>
# 2047523094 <class 'telethon.tl.types.PeerChannel'>
# 1817501983 <class 'telethon.tl.types.PeerChannel'>
# 1437513127 <class 'telethon.tl.types.PeerChannel'>
# 1191718693 <class 'telethon.tl.types.PeerChannel'>
# 1883734379 <class 'telethon.tl.types.PeerChannel'>
# 1381367674 <class 'telethon.tl.types.PeerChannel'>
# 1646366810 <class 'telethon.tl.types.PeerChannel'>
# 1242622519 <class 'telethon.tl.types.PeerChannel'>
# 931946713 <class 'telethon.tl.types.PeerUser'>
# 1946445341 <class 'telethon.tl.types.PeerChannel'>
# 1229601342 <class 'telethon.tl.types.PeerChannel'>
# 137495865 <class 'telethon.tl.types.PeerUser'>
# 1328916283 <class 'telethon.tl.types.PeerChannel'>
# 1747765554 <class 'telethon.tl.types.PeerChannel'>
# 1229555429 <class 'telethon.tl.types.PeerChannel'>
# 273270523 <class 'telethon.tl.types.PeerUser'>
# 650172704 <class 'telethon.tl.types.PeerUser'>
# 1710810911 <class 'telethon.tl.types.PeerChannel'>
# 419143578 <class 'telethon.tl.types.PeerUser'>
# 1336278230 <class 'telethon.tl.types.PeerChannel'>
# 1375250925 <class 'telethon.tl.types.PeerChannel'>
# 429000 <class 'telethon.tl.types.PeerUser'>
# 5556297854 <class 'telethon.tl.types.PeerUser'>
# 457519984 <class 'telethon.tl.types.PeerUser'>
# 1197202408 <class 'telethon.tl.types.PeerChannel'>
# 5716333972 <class 'telethon.tl.types.PeerUser'>
# 331368031 <class 'telethon.tl.types.PeerUser'>
# 459323414 <class 'telethon.tl.types.PeerUser'>
# 1452132999 <class 'telethon.tl.types.PeerChannel'>
# 1139650997 <class 'telethon.tl.types.PeerChannel'>
# 1573874027 <class 'telethon.tl.types.PeerChannel'>
# 455538594 <class 'telethon.tl.types.PeerUser'>
# 7092290010 <class 'telethon.tl.types.PeerUser'>
# 597248291 <class 'telethon.tl.types.PeerUser'>
# 100705452 <class 'telethon.tl.types.PeerUser'>
# 7148791415 <class 'telethon.tl.types.PeerUser'>
# 1271266957 <class 'telethon.tl.types.PeerUser'>
# 1962403786 <class 'telethon.tl.types.PeerChannel'>
# 7128156001 <class 'telethon.tl.types.PeerUser'>
# 1840403411 <class 'telethon.tl.types.PeerUser'>
# 6650991877 <class 'telethon.tl.types.PeerUser'>
# 7003322634 <class 'telethon.tl.types.PeerUser'>
# 682809254 <class 'telethon.tl.types.PeerUser'>
# 685640865 <class 'telethon.tl.types.PeerUser'>
# 1419113824 <class 'telethon.tl.types.PeerChannel'>
# 1509515124 <class 'telethon.tl.types.PeerChannel'>
# 496399347 <class 'telethon.tl.types.PeerUser'>
# 1462763966 <class 'telethon.tl.types.PeerChannel'>
# 1222200291 <class 'telethon.tl.types.PeerChannel'>
# 231538800 <class 'telethon.tl.types.PeerUser'>
# 93372553 <class 'telethon.tl.types.PeerUser'>
# 220255550 <class 'telethon.tl.types.PeerUser'>
# 55207952 <class 'telethon.tl.types.PeerUser'>
# 104237989 <class 'telethon.tl.types.PeerUser'>
# 974938162 <class 'telethon.tl.types.PeerUser'>
# 5832737980 <class 'telethon.tl.types.PeerUser'>
# 6901051742 <class 'telethon.tl.types.PeerUser'>
# 6848920675 <class 'telethon.tl.types.PeerUser'>
# 237050818 <class 'telethon.tl.types.PeerUser'>
# 1355185734 <class 'telethon.tl.types.PeerChannel'>
# 1165118707 <class 'telethon.tl.types.PeerUser'>
# 5472743372 <class 'telethon.tl.types.PeerUser'>
# 1671174017 <class 'telethon.tl.types.PeerUser'>
# 1630064994 <class 'telethon.tl.types.PeerChannel'>
# 1885977785 <class 'telethon.tl.types.PeerUser'>
# 6345709199 <class 'telethon.tl.types.PeerUser'>
# 179060879 <class 'telethon.tl.types.PeerUser'>
# 405173937 <class 'telethon.tl.types.PeerUser'>
# 5873130340 <class 'telethon.tl.types.PeerUser'>
# 128138257 <class 'telethon.tl.types.PeerUser'>
# 383446135 <class 'telethon.tl.types.PeerUser'>
# 2013603958 <class 'telethon.tl.types.PeerUser'>
# 2124364197 <class 'telethon.tl.types.PeerUser'>
# 125077702 <class 'telethon.tl.types.PeerUser'>
# 666467426 <class 'telethon.tl.types.PeerUser'>
# 327612125 <class 'telethon.tl.types.PeerUser'>
# 494018881 <class 'telethon.tl.types.PeerUser'>
# 288460698 <class 'telethon.tl.types.PeerUser'>
# 6853190070 <class 'telethon.tl.types.PeerUser'>
# 690397430 <class 'telethon.tl.types.PeerUser'>
# 6291320116 <class 'telethon.tl.types.PeerUser'>
# 6896340043 <class 'telethon.tl.types.PeerUser'>
# 1316436289 <class 'telethon.tl.types.PeerChannel'>
# 6932829831 <class 'telethon.tl.types.PeerUser'>
# 1866658835 <class 'telethon.tl.types.PeerChannel'>
# 1452331943 <class 'telethon.tl.types.PeerChannel'>
# 1449266499 <class 'telethon.tl.types.PeerChannel'>
# 1587677000 <class 'telethon.tl.types.PeerChannel'>
# 6786484226 <class 'telethon.tl.types.PeerUser'>
# 6385805483 <class 'telethon.tl.types.PeerUser'>
# 119725480 <class 'telethon.tl.types.PeerUser'>
# 1271450611 <class 'telethon.tl.types.PeerUser'>
# 6016007027 <class 'telethon.tl.types.PeerUser'>
# 316485496 <class 'telethon.tl.types.PeerUser'>
# 1448600883 <class 'telethon.tl.types.PeerUser'>
# 5676474650 <class 'telethon.tl.types.PeerUser'>
# 1475350325 <class 'telethon.tl.types.PeerChannel'>
# 1187716722 <class 'telethon.tl.types.PeerChannel'>
# 6356000283 <class 'telethon.tl.types.PeerUser'>
# 6305348097 <class 'telethon.tl.types.PeerUser'>
# 6638766409 <class 'telethon.tl.types.PeerUser'>
# 6487678639 <class 'telethon.tl.types.PeerUser'>
# 6403009332 <class 'telethon.tl.types.PeerUser'>
# 6078224925 <class 'telethon.tl.types.PeerUser'>
# 5821330346 <class 'telethon.tl.types.PeerUser'>
# 6087757770 <class 'telethon.tl.types.PeerUser'>
# 6192075808 <class 'telethon.tl.types.PeerUser'>
# 288967082 <class 'telethon.tl.types.PeerUser'>
# 6176976775 <class 'telethon.tl.types.PeerUser'>
# 949346762 <class 'telethon.tl.types.PeerUser'>
# 6273655571 <class 'telethon.tl.types.PeerUser'>
# 6149815293 <class 'telethon.tl.types.PeerUser'>
# 795170144 <class 'telethon.tl.types.PeerUser'>
# 5900356004 <class 'telethon.tl.types.PeerUser'>
# 5617955908 <class 'telethon.tl.types.PeerUser'>
# 392483645 <class 'telethon.tl.types.PeerUser'>
# 254515265 <class 'telethon.tl.types.PeerUser'>
# 740380220 <class 'telethon.tl.types.PeerUser'>
# 2060449177 <class 'telethon.tl.types.PeerUser'>
# 704737939 <class 'telethon.tl.types.PeerChat'>
# 1335113981 <class 'telethon.tl.types.PeerChannel'>
# 1939632533 <class 'telethon.tl.types.PeerUser'>
# 5940594434 <class 'telethon.tl.types.PeerUser'>
# 1459689252 <class 'telethon.tl.types.PeerUser'>
# 1559675137 <class 'telethon.tl.types.PeerUser'>
# 200531074 <class 'telethon.tl.types.PeerUser'>
# 358740365 <class 'telethon.tl.types.PeerUser'>
# 53765321 <class 'telethon.tl.types.PeerUser'>
# 6010576841 <class 'telethon.tl.types.PeerUser'>
# 1533966022 <class 'telethon.tl.types.PeerUser'>
# 197397698 <class 'telethon.tl.types.PeerUser'>
# 402393581 <class 'telethon.tl.types.PeerUser'>
# 231326490 <class 'telethon.tl.types.PeerUser'>
# 1761759680 <class 'telethon.tl.types.PeerChannel'>
# 1873136343 <class 'telethon.tl.types.PeerChannel'>
# 779394812 <class 'telethon.tl.types.PeerUser'>
# 660783114 <class 'telethon.tl.types.PeerUser'>
# 5894436949 <class 'telethon.tl.types.PeerUser'>
# 266893278 <class 'telethon.tl.types.PeerUser'>
# 6064360271 <class 'telethon.tl.types.PeerUser'>
# 1728245662 <class 'telethon.tl.types.PeerChannel'>
# 5946416386 <class 'telethon.tl.types.PeerUser'>
# 1237063455 <class 'telethon.tl.types.PeerUser'>
# 931812468 <class 'telethon.tl.types.PeerUser'>
# 5104055776 <class 'telethon.tl.types.PeerUser'>
# 118999474 <class 'telethon.tl.types.PeerUser'>
# 570702434 <class 'telethon.tl.types.PeerUser'>
# 6171678288 <class 'telethon.tl.types.PeerUser'>
# 1296409665 <class 'telethon.tl.types.PeerChannel'>
# 102869086 <class 'telethon.tl.types.PeerUser'>
# 961068366 <class 'telethon.tl.types.PeerUser'>
# 276876673 <class 'telethon.tl.types.PeerUser'>
# 1955175594 <class 'telethon.tl.types.PeerUser'>
# 460043272 <class 'telethon.tl.types.PeerUser'>
# 1547312931 <class 'telethon.tl.types.PeerChannel'>
# 1056495544 <class 'telethon.tl.types.PeerUser'>
# 1669257416 <class 'telethon.tl.types.PeerUser'>
# 197730900 <class 'telethon.tl.types.PeerUser'>
# 406144131 <class 'telethon.tl.types.PeerUser'>
# 5314653481 <class 'telethon.tl.types.PeerUser'>
# 5560694732 <class 'telethon.tl.types.PeerUser'>
# 1053846245 <class 'telethon.tl.types.PeerUser'>
# 1532501592 <class 'telethon.tl.types.PeerChannel'>
# 895847578 <class 'telethon.tl.types.PeerUser'>
# 277084542 <class 'telethon.tl.types.PeerUser'>
# 1633643838 <class 'telethon.tl.types.PeerChannel'>
# 1480752748 <class 'telethon.tl.types.PeerChannel'>
# 132869564 <class 'telethon.tl.types.PeerUser'>
# 1141186087 <class 'telethon.tl.types.PeerChannel'>
# 2026910701 <class 'telethon.tl.types.PeerUser'>
# 721370419 <class 'telethon.tl.types.PeerUser'>
# 5613845521 <class 'telethon.tl.types.PeerUser'>
# 5572268829 <class 'telethon.tl.types.PeerUser'>
# 5596705047 <class 'telethon.tl.types.PeerUser'>
# 1384997707 <class 'telethon.tl.types.PeerChannel'>
# 5366072031 <class 'telethon.tl.types.PeerUser'>
# 5189263990 <class 'telethon.tl.types.PeerUser'>
# 5296767747 <class 'telethon.tl.types.PeerUser'>
# 5286482907 <class 'telethon.tl.types.PeerUser'>
# 5272712349 <class 'telethon.tl.types.PeerUser'>
# 5094798504 <class 'telethon.tl.types.PeerUser'>
# 2115333206 <class 'telethon.tl.types.PeerUser'>
# 2038370579 <class 'telethon.tl.types.PeerUser'>
# 2098499959 <class 'telethon.tl.types.PeerUser'>
# 2085167779 <class 'telethon.tl.types.PeerUser'>
# 2042936135 <class 'telethon.tl.types.PeerUser'>
# 1948961127 <class 'telethon.tl.types.PeerUser'>
# 1793423187 <class 'telethon.tl.types.PeerUser'>
# 1656781791 <class 'telethon.tl.types.PeerUser'>
# 1783586856 <class 'telethon.tl.types.PeerUser'>
# 1798967357 <class 'telethon.tl.types.PeerUser'>
# 1728547586 <class 'telethon.tl.types.PeerUser'>
# 1792633081 <class 'telethon.tl.types.PeerUser'>
# 1570302843 <class 'telethon.tl.types.PeerUser'>
# 1451490137 <class 'telethon.tl.types.PeerUser'>
# 1406301956 <class 'telethon.tl.types.PeerUser'>
# 1365310556 <class 'telethon.tl.types.PeerUser'>
# 1292943906 <class 'telethon.tl.types.PeerUser'>
# 1245667418 <class 'telethon.tl.types.PeerUser'>
# 1167051633 <class 'telethon.tl.types.PeerUser'>

# %%
# Find recent messages in a chat
filtered = filter(lambda dialog: dialog.name.find('Abrahams') > -1, dialogs)
f: telethon.tl.custom.dialog.Dialog = next(filtered)
last_messages = await client.get_messages(f, limit=20)

[print(m) for m in last_messages]
# Out:
# Message(id=112883, peer_id=PeerUser(user_id=7148791415), date=datetime.datetime(2024, 5, 16, 22, 7, 22, tzinfo=datetime.timezone.utc), message='Good boy', out=False, mentioned=False, media_unread=False, silent=False, post=False, from_scheduled=False, legacy=False, edit_hide=False, pinned=False, noforwards=False, invert_media=False, offline=False, from_id=None, from_boosts_applied=None, saved_peer_id=None, fwd_from=None, via_bot_id=None, via_business_bot_id=None, reply_to=None, media=None, reply_markup=None, entities=[], views=None, forwards=None, replies=None, edit_date=None, post_author=None, grouped_id=None, reactions=None, restriction_reason=[], ttl_period=None, quick_reply_shortcut_id=None, effect=None, factcheck=None)
# Message(id=112473, peer_id=PeerUser(user_id=7148791415), date=datetime.datetime(2024, 5, 15, 15, 47, 57, tzinfo=datetime.timezone.utc), message='', out=True, mentioned=False, media_unread=False, silent=False, post=False, from_scheduled=False, legacy=False, edit_hide=False, pinned=False, noforwards=False, invert_media=False, offline=False, from_id=PeerUser(user_id=1150680064), from_boosts_applied=None, saved_peer_id=None, fwd_from=None, via_bot_id=None, via_business_bot_id=None, reply_to=None, media=MessageMediaDocument(nopremium=False, spoiler=False, video=False, round=False, voice=False, document=Document(id=775773945239437349, access_hash=8942478443023087445, file_reference=b'\x03\x00\x01\xb7Yf\x94p\xa7\xe0\x8ek\xa5\xeco\xa9v\x83\xc5\x9e\xafO>(\xbb', date=datetime.datetime(2017, 12, 11, 5, 1, 15, tzinfo=datetime.timezone.utc), mime_type='image/webp', size=41596, dc_id=1, attributes=[DocumentAttributeImageSize(w=512, h=512), DocumentAttributeSticker(alt='💦', stickerset=InputStickerSetID(id=775773945239437314, access_hash=5381931294508306910), mask=False, mask_coords=None), DocumentAttributeFilename(file_name='sticker.webp')], thumbs=[PhotoPathSize(type='j', bytes=b'\x1b\x02\xb3\x02\xdcz\x80K\x06\x80Q\x05\x80D\x80o\x83lE\x8a]\x89\x00m\xb3G\x06DCH\x89K\x86NIVWb_DCd\x99q\x92OI\xa5K\x01\xadK\x07\x89G\x94I\x9cR\x89J``\x81p\x87D\xa5O\xa4XDid_F\toBB`YNX\x85\x80\x88\x82\x8e\x81\x9aCBB\x82I\x87M\xa3F\xabQ\x87KHa\x88i\x86D\x96\x95\x9b\x99\x82\x81\x9fK\xa0M\x82GCt\x8er\x93\x83\x9e\xb0\xb4\xaa\x8aCCT\x84_\x9ag\xa4B\xb6\x86\x84\x81\x83H\x86J\x84B\x89\x80\x8c\x82\x99\x8fa\xb4P\x86\x06\x86\x85\x8du\xb0n\x87\x81\x8c\x8e\x91\x8e\xa2\x84\x91\x8d\x99\xb0\x81\x86\x88\x8f\x8d\x8c\x82AAXA\\\x81H\x8aM\x90F\x8d\x93\x82\xa8\x87\xbb\x87\xa3\xa6\xac\xb6\x87\x02\x88\x8fI\x8cM\x91B\x83\x82\x9f\x84\xa4\x90\xbf\x87\x03\x8f\x00\xa1\x95\x04B\x82S\x07\x83U\x08\x83'), PhotoSize(type='m', w=128, h=128, size=7364)], video_thumbs=[]), alt_document=None, ttl_seconds=None), reply_markup=None, entities=[], views=None, forwards=None, replies=None, edit_date=None, post_author=None, grouped_id=None, reactions=None, restriction_reason=[], ttl_period=None, quick_reply_shortcut_id=None, effect=None, factcheck=None)
# MessageService(id=112472, peer_id=PeerUser(user_id=7148791415), date=datetime.datetime(2024, 5, 15, 15, 43, 16, tzinfo=datetime.timezone.utc), action=MessageActionContactSignUp(), out=False, mentioned=False, media_unread=False, silent=False, post=False, legacy=False, from_id=None, reply_to=None, ttl_period=None)
# [None, None, None]

# %%
# Delete most recent message
# await client.delete_messages(f, last_messages[0], revoke=True)

# %%
chatFolders: DialogFilters = await client(functions.messages.GetDialogFiltersRequest())
# print(chatFolders.stringify())

# %%
mediaFolder = None
for folder in chatFolders.filters:
    if not hasattr(folder, 'title'):
        continue
    if folder.title == 'MediaView':
        mediaFolder = folder
        break

# print(mediaFolder.stringify())

# %%
# target_channels = [dialog_by_id[peer.channel_id] for peer in mediaFolder.include_peers]
# target_channels = [client.get_entity(peer) for peer in mediaFolder.include_peers]
# await client.get_entity(peer)

target_channels = await asyncio.gather(*[client.get_entity(peer) for peer in mediaFolder.include_peers])
for channel in target_channels:
    print(channel.stringify())
# Out:
# Channel(
# 	id=1853857944,
# 	title='Vore: Snack➡️Scat',
# 	photo=ChatPhoto(
# 		photo_id=5098206183164062343,
# 		dc_id=1,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08\xa5+y\x84\xee\xc2\x81\xd0\x0e\xd4QE+\xdci$\x7f'
# 	),
# 	date=datetime.datetime(2023, 1, 16, 23, 37, 37, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=False,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=6312540377902597213,
# 	username='furry_disposal',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1209919139,
# 	title='Vores "R" Us',
# 	photo=ChatPhoto(
# 		photo_id=4904949594195077648,
# 		dc_id=1,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08\x8a$id\xf3q\xf3\x06\xe0\x9a(\xa2\x84\x0c'
# 	),
# 	date=datetime.datetime(2024, 5, 6, 4, 56, 14, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=True,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=False,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=-1776413402268666983,
# 	username='VoresAreUs',
# 	restriction_reason=[
# 		RestrictionReason(
# 			platform='ios',
# 			reason='porn',
# 			text='This channel can’t be displayed because it was used to spread pornographic content.'
# 		),
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1426223303,
# 	title="Nathan's vore library",
# 	photo=ChatPhoto(
# 		photo_id=5026564264650976271,
# 		dc_id=1,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08\xa3\xc7SE\x14T\x9d2V\xb2?'
# 	),
# 	date=datetime.datetime(2024, 6, 18, 17, 50, 22, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=-1401347112577188138,
# 	username='vorelibraryprettymuch',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1160487164,
# 	title='Vore Cave',
# 	photo=ChatPhoto(
# 		photo_id=5819057366522510531,
# 		dc_id=4,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08\x8fl\x1fe\xce\x07\x97\x8e\xb4QEBEsy\x1f'
# 	),
# 	date=datetime.datetime(2024, 1, 25, 5, 18, 34, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=True,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=-1247061625643424232,
# 	username='VoreCaveOriginal',
# 	restriction_reason=[
# 		RestrictionReason(
# 			platform='ios',
# 			reason='porn',
# 			text='This channel can’t be displayed because it was used to spread pornographic content.'
# 		),
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1194004105,
# 	title='Vore Stream',
# 	photo=ChatPhoto(
# 		photo_id=5102856593363544454,
# 		dc_id=1,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08j2,l@m\xc4\xf4=\xfd\xe8\xa2\x8a\x0b?'
# 	),
# 	date=datetime.datetime(2023, 3, 12, 15, 12, 44, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=True,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=False,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=-5754630827738961831,
# 	username='nsfwvorestream',
# 	restriction_reason=[
# 		RestrictionReason(
# 			platform='ios',
# 			reason='porn',
# 			text='This channel can’t be displayed because it was used to spread pornographic content.'
# 		),
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1419113824,
# 	title="Joevis's post vore (18+ ONLY) disposal art channel",
# 	photo=ChatPhoto(
# 		photo_id=5130136688029444374,
# 		dc_id=1,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08\xb7\x8eh\xa2\x8a\x04\x7f'
# 	),
# 	date=datetime.datetime(2022, 11, 27, 13, 14, 1, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=-1258012889288736836,
# 	username='PostVoreDisposalShhSecritChannel',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1092325450,
# 	title='VoreGifs [NSFW]',
# 	photo=ChatPhoto(
# 		photo_id=215569343959909048,
# 		dc_id=1,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08\xb5\x0b[l\x11\xe0\x06\xc63E\x14UXm\x1f'
# 	),
# 	date=datetime.datetime(2024, 6, 18, 17, 52, 47, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=False,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=-8504595689817158984,
# 	username='voregifs',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1344946756,
# 	title="Vore 'n Stuff +18",
# 	photo=ChatPhoto(
# 		photo_id=4913741233336200223,
# 		dc_id=1,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08\x8as\xb0\x99\x03\xbe\xec\xf1\xcfJ(\xa2\xaa*\xe8l'
# 	),
# 	date=datetime.datetime(2023, 1, 12, 18, 9, 33, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=True,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=135314353449045199,
# 	username='LewdFurryVore',
# 	restriction_reason=[
# 		RestrictionReason(
# 			platform='ios',
# 			reason='porn',
# 			text='This channel can’t be displayed because it was used to spread pornographic content.'
# 		),
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1227354457,
# 	title='The Vore & Scat Art Of Fodder Fox',
# 	photo=ChatPhoto(
# 		photo_id=4994884847868684837,
# 		dc_id=1,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08I\xd7\t\x9cn=\xb2zQE\x15\x8cv\x19'
# 	),
# 	date=datetime.datetime(2023, 5, 19, 2, 35, 14, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=7130293134788703512,
# 	username='VoreArtOfFodderFox',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1801177686,
# 	title='Vore Cave Aftermath',
# 	photo=ChatPhoto(
# 		photo_id=5922619816986919920,
# 		dc_id=4,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08\xa4\x01\xeb\xda\x8a(\xa8\xe6e\x1f'
# 	),
# 	date=datetime.datetime(2023, 8, 1, 20, 23, 59, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=-1740352403772049484,
# 	username='VoreCaveAftermath',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1692224524,
# 	title='Caster art',
# 	photo=ChatPhoto(
# 		photo_id=5744761450278266807,
# 		dc_id=1,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08\x95\xe0eD;H\xcfS\xe9E\x14V\\\xcc\xab\x1f'
# 	),
# 	date=datetime.datetime(2024, 6, 18, 17, 54, 29, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=-2084092216638460618,
# 	username='the_dog_who_ate_everything',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1816668235,
# 	title="Wild's Art Channel (18+ Only)",
# 	photo=ChatPhoto(
# 		photo_id=5037528053437278939,
# 		dc_id=1,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08\x84\xabgi g\x03o\xaf\xff\x00^\x8a(\xa8rq\xd8\xd9\xb6\xb6?'
# 	),
# 	date=datetime.datetime(2024, 6, 18, 17, 53, 7, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=7189094654017076740,
# 	username='wildyena',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=3
# )
# Channel(
# 	id=1214855655,
# 	title='The Macro Channel',
# 	photo=ChatPhoto(
# 		photo_id=6336761282589470911,
# 		dc_id=5,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08\xbc^_\xb5\x85\t&3\xd7\xf8H\xa2\x8a(\x1bg'
# 	),
# 	date=datetime.datetime(2024, 6, 18, 17, 59, 50, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=-4523585676928768919,
# 	username='macrochannel',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=2022414023,
# 	title='Junk cave',
# 	photo=ChatPhoto(
# 		photo_id=5976525522022285536,
# 		dc_id=4,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08\xcci\x13\xc9\n\x13\xe6\xcewg\xb7\xa5\x14QM\x81'
# 	),
# 	date=datetime.datetime(2023, 12, 14, 21, 19, 29, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=-2108406870976413956,
# 	username='JunkCave',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1539142705,
# 	title='🔞 N00dle & D00dle 🔞',
# 	photo=ChatPhoto(
# 		photo_id=4920294838033820770,
# 		dc_id=1,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08\xcc\xc6S\xa7N\xf4QEI\xa5\x8f'
# 	),
# 	date=datetime.datetime(2024, 6, 18, 17, 52, 54, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=-9023426354743681084,
# 	username='n00dleNd00dle',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1407468739,
# 	title='ZillaStudio Channel',
# 	photo=ChatPhoto(
# 		photo_id=5866251137185854331,
# 		dc_id=4,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08\x85U1\xb8\xfaQE\x14\xc8g'
# 	),
# 	date=datetime.datetime(2024, 6, 18, 18, 1, 5, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=-1365266296047617763,
# 	username='zillastudiochannel',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1826739658,
# 	title="Aero's Art Zone",
# 	photo=ChatPhoto(
# 		photo_id=5154525715654355816,
# 		dc_id=1,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08q\xb7\x96f&E\x1ct\xcfJ(\xa2\x93@\x99'
# 	),
# 	date=datetime.datetime(2024, 6, 18, 18, 0, 48, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=-4985973373492900506,
# 	username='aeronusart',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1424981263,
# 	title='🔞🔞Zawnart (NSFW)🔞🔞',
# 	photo=ChatPhoto(
# 		photo_id=5003552783361748001,
# 		dc_id=1,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08\xaf\x03?\x9f\x9c1?\xc5\x8e\xf4QED\xa9\xa9=J\x8c\xda?'
# 	),
# 	date=datetime.datetime(2024, 6, 18, 18, 0, 53, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=-8748446880151396929,
# 	username='Zawnart',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1321716884,
# 	title="🔞Smol Max's Art Library (NSFW 18+ only)",
# 	photo=ChatPhoto(
# 		photo_id=4933981099214875324,
# 		dc_id=1,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08\xac\xb0y\x96\xb3\xb6\xc62\x83\xc1\xc7^{QE\x15\x9f1v?'
# 	),
# 	date=datetime.datetime(2023, 4, 18, 23, 58, 52, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=32257444190923069,
# 	username='Maxs_Macro_Micro_Art',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1941293920,
# 	title="Loxy's day and stuff",
# 	photo=ChatPhoto(
# 		photo_id=6289464445595923719,
# 		dc_id=5,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08\x93\xcf\x89\x82\xe0\xed#\xa9\x03\xbd\x14QW\x1b\xb4c($\xcf'
# 	),
# 	date=datetime.datetime(2023, 7, 20, 9, 7, 58, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=3008415312335385032,
# 	username='Loxysohak',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1255674377,
# 	title='Goat Extravaganza 🔞',
# 	photo=ChatPhoto(
# 		photo_id=5237966313056486400,
# 		dc_id=2,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08\\|\x9c\xfaQE\x15\xd4\x8aG'
# 	),
# 	date=datetime.datetime(2024, 6, 18, 17, 56, 54, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=4611892398084078814,
# 	username='GoatExtravaganza',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1475867202,
# 	title="Silly werewolf's lair 🔞",
# 	photo=ChatPhoto(
# 		photo_id=5220101284919625317,
# 		dc_id=2,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08\xcfs\x93E\x14R\xdfVh\xf4?'
# 	),
# 	date=datetime.datetime(2024, 6, 18, 17, 59, 5, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=1750429058724323417,
# 	username='Sillywerwolfarts',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1466638826,
# 	title="Corvidius's Works",
# 	photo=ChatPhoto(
# 		photo_id=4924991393361930473,
# 		dc_id=1,
# 		has_video=True,
# 		stripped_thumb=b'\x01\x08\x08|\xb7\xa9*\x90wm\x03\x91\x8e\xb4QER\x03'
# 	),
# 	date=datetime.datetime(2024, 6, 18, 17, 59, 27, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=-2581238368677995016,
# 	username='CorvWorks',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=PeerColor(
# 		color=2,
# 		background_emoji_id=None
# 	),
# 	profile_color=None,
# 	emoji_status=None,
# 	level=1
# )
# Channel(
# 	id=1469894855,
# 	title='The Channel of Macro GIFs and Vids',
# 	photo=ChatPhoto(
# 		photo_id=5994532490238343421,
# 		dc_id=4,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08f\xf8\x1a\x02\xdb\x88p8\xcf_\xff\x00U\x14QTA'
# 	),
# 	date=datetime.datetime(2024, 6, 18, 17, 59, 17, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=6234361089529952498,
# 	username='MacroGIFs',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1754989111,
# 	title='Maneymaw - The mean maney den!',
# 	photo=ChatPhoto(
# 		photo_id=4988021168007129742,
# 		dc_id=1,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08i\x94\xb4S1\x7f1pp6\xf4\xe7\xad\x14QSb\x9e\x87'
# 	),
# 	date=datetime.datetime(2024, 6, 18, 18, 1, 56, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=-6356971103905027191,
# 	username='maneymaw',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1330169550,
# 	title='FeedTheBeast Channel',
# 	photo=ChatPhoto(
# 		photo_id=5879934602343202009,
# 		dc_id=4,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08k)9u%{\x97\xcf\x14QE2\x0f'
# 	),
# 	date=datetime.datetime(2023, 3, 16, 18, 57, 6, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=-5187072666415238482,
# 	username=None,
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1312841387,
# 	title='Macro gallery',
# 	photo=ChatPhoto(
# 		photo_id=5391002435968942960,
# 		dc_id=2,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08k}\xa7\xed\xe4\x8c\xef\xcf\xad\x14Q@\x8f'
# 	),
# 	date=datetime.datetime(2024, 6, 18, 17, 59, 47, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=False,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=1678118932228290525,
# 	username='macro_gallery',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )
# Channel(
# 	id=1381367674,
# 	title='πVore Drawingsπ',
# 	photo=ChatPhoto(
# 		photo_id=5938479396044256303,
# 		dc_id=4,
# 		has_video=False,
# 		stripped_thumb=b'\x01\x08\x08q#\xca\xc8 6(\xa2\x8a\x00'
# 	),
# 	date=datetime.datetime(2024, 6, 18, 17, 56, tzinfo=datetime.timezone.utc),
# 	creator=False,
# 	left=False,
# 	broadcast=True,
# 	verified=False,
# 	megagroup=False,
# 	restricted=False,
# 	signatures=False,
# 	min=False,
# 	scam=False,
# 	has_link=True,
# 	has_geo=False,
# 	slowmode_enabled=False,
# 	call_active=False,
# 	call_not_empty=False,
# 	fake=False,
# 	gigagroup=False,
# 	noforwards=False,
# 	join_to_send=False,
# 	join_request=False,
# 	forum=False,
# 	stories_hidden=False,
# 	stories_hidden_min=False,
# 	stories_unavailable=True,
# 	access_hash=-3749841139264914690,
# 	username='PiVore',
# 	restriction_reason=[
# 	],
# 	admin_rights=None,
# 	banned_rights=None,
# 	default_banned_rights=None,
# 	participants_count=None,
# 	usernames=[
# 	],
# 	stories_max_id=None,
# 	color=None,
# 	profile_color=None,
# 	emoji_status=None,
# 	level=None
# )

# %%
# Test messages in the first two channels
"""
for channel_id in target_channels[0:2]:
    async for message in client.iter_messages(channel_id, limit=5):
        print(message.stringify())
"""

# Grab most recent post @ self to test twitter embed
test_message = None
async for message in client.iter_messages('me', limit=1):
    test_message = message

print(test_message.stringify())

# test_message.media = MessageMediaWebPage
print(test_message.document)
# Out:
# Message(
# 	id=127610,
# 	peer_id=PeerUser(
# 		user_id=1150680064
# 	),
# 	date=datetime.datetime(2024, 7, 15, 0, 43, 17, tzinfo=datetime.timezone.utc),
# 	message='Cool!',
# 	out=True,
# 	mentioned=False,
# 	media_unread=False,
# 	silent=False,
# 	post=False,
# 	from_scheduled=False,
# 	legacy=False,
# 	edit_hide=False,
# 	pinned=False,
# 	noforwards=False,
# 	invert_media=False,
# 	offline=False,
# 	from_id=None,
# 	from_boosts_applied=None,
# 	saved_peer_id=PeerUser(
# 		user_id=1150680064
# 	),
# 	fwd_from=None,
# 	via_bot_id=None,
# 	via_business_bot_id=None,
# 	reply_to=MessageReplyHeader(
# 		reply_to_scheduled=False,
# 		forum_topic=False,
# 		quote=False,
# 		reply_to_msg_id=127609,
# 		reply_to_peer_id=None,
# 		reply_from=None,
# 		reply_media=None,
# 		reply_to_top_id=None,
# 		quote_text=None,
# 		quote_entities=[
# 		],
# 		quote_offset=None
# 	),
# 	media=None,
# 	reply_markup=None,
# 	entities=[
# 	],
# 	views=None,
# 	forwards=None,
# 	replies=None,
# 	edit_date=None,
# 	post_author=None,
# 	grouped_id=None,
# 	reactions=None,
# 	restriction_reason=[
# 	],
# 	ttl_period=None,
# 	quick_reply_shortcut_id=None,
# 	effect=None,
# 	factcheck=None
# )
# None

# %%
"""
async def collect_posts(client, target_channels, limit=5):
    post_collection = []
    for channel in target_channels:
        async for message in client.iter_messages(channel, limit=limit):
            post_collection.append(message)
    return post_collection
posts = await collect_posts(client, target_channels, limit=5)
"""
# Out:
# '\nasync def collect_posts(client, target_channels, limit=5):\n    post_collection = []\n    for channel in target_channels:\n        async for message in client.iter_messages(channel, limit=limit):\n            post_collection.append(message)\n    return post_collection\nposts = await collect_posts(client, target_channels, limit=5)\n'

# %% [markdown]
# ## Older version

# %%
async def get_media_info(client, message: Message, channel: Channel, downloaded_files: Dict[str, str]) -> Dict[str, Any]:
    media_info = {
        'id': message.id,
        'date': str(message.date),  # Convert to string for JSON serialization
        'channel': channel.title,
        'text': message.text,  # Include message text
    }

    if message.file:
        file_id = message.file.id
        if file_id in downloaded_files:
            media_info['path'] = downloaded_files[file_id]
        else:
            media_info['path'] = await download_media(client, message)
            downloaded_files[file_id] = media_info['path']

        if message.photo:
            media_type = 'photo'
        elif message.gif:
            media_type = 'gif'
        elif message.video:
            media_type = 'video'
        elif message.document:
            mime_type = message.document.mime_type
            media_type = mime_type.split('/')[-1] if 'image/' in mime_type else 'document'
        else:
            media_type = 'unknown'

        media_info.update({
            'type': media_type,
            'file_id': file_id,
            'file_name': message.file.name,
            'file_size': message.file.size,
        })
    elif message.web_preview:
        media_info.update({
            'type': 'web_preview',
            'url': message.web_preview.url,
        })
    else:
        return None

    return media_info

async def collect_media(client, message_collection: List[Message], channels: Dict[int, Channel]) -> List[Dict[str, Any]]:
    media_collection = []
    downloaded_files = {}
    for message in tqdm(message_collection):
        channel = channels.get(message.peer_id.channel_id)
        media_info = await get_media_info(client, message, channel, downloaded_files)
        if media_info:
            media_collection.append(media_info)
            print(f"Has {media_info['type']}: {message.id}")
        else:
            print(f"No media found: {message.id}")
    return media_collection


# Export to JSON
def json_serial(obj):
    """JSON serializer for objects not serializable by default json code"""

    if isinstance(obj, (datetime, date)):
        return obj.isoformat()
    elif isinstance(obj, telethon.tl.custom.file.File):
        return json.dumps({
            'id': obj.id, 'name': obj.name, 'ext': obj.ext, 'mime_type': obj.mime_type})
    elif hasattr(obj, 'stringify'):
        return obj.stringify()
    raise TypeError ("Type %s not serializable" % type(obj))

def export_to_json(media_collection: List[Dict[str, Any]], filename: str = 'media_data.json') -> None:
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(media_collection, f, ensure_ascii=False, indent=2, default=json_serial)
    print(f"Media data exported to {filename}")





### NEW CODE ###

# SQLite database setup
db_path = './GOTTH/goth.db'
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

# Create table if it doesn't exist
cursor.execute('''
CREATE TABLE IF NOT EXISTS media_items (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    file_id TEXT UNIQUE,
    date DATETIME,
    channel TEXT,
    text TEXT,
    type TEXT,
    file_name TEXT,
    file_size INTEGER,
    url TEXT
)
''')
conn.commit()


async def process_channel(client, channel):
    download_folder = './static/media/'
    os.makedirs(download_folder, exist_ok=True)

    async for message in client.iter_messages(channel, limit=10):  # Adjust limit as needed
        if message.media:
            file_path = await download_media(client, message, download_folder)
            if file_path:
                file_name = os.path.basename(file_path)
                file_id = message.file.id if message.file else None
                media_type = message.file.mime_type.split('/')[0] if message.file else 'unknown'

                cursor.execute('''
                INSERT OR REPLACE INTO media_items
                (file_id, date, channel, text, type, file_name, file_size, url)
                VALUES (?, ?, ?, ?, ?, ?, ?, ?)
                ''', (
                    file_id,
                    message.date,
                    channel.title,
                    message.text,
                    media_type,
                    file_name,
                    message.file.size if message.file else 0,
                    f'/media/{file_name}'
                ))
                conn.commit()

conn.close()
await client.disconnect()

# %% [markdown]
# ## New version

# %%
client = TelegramClient(username, api_id, api_hash)
await client.connect()

# SQLite database setup
conn = sqlite3.connect(DB_PATH)
cursor = conn.cursor()

# %%
# Create table if it doesn't exist
cursor.execute('''
CREATE TABLE IF NOT EXISTS media_items (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    file_id TEXT UNIQUE,
    date DATETIME,
    channel TEXT,
    text TEXT,
    type TEXT,
    file_name TEXT,
    file_size INTEGER,
    url TEXT
)
''')
conn.commit()


async def collect_posts(client, target_channels: List[Channel], limit: int = 10) -> List[Message]:
    return [message for channel in target_channels
            async for message in client.iter_messages(channel, limit=limit)]

async def process_message(client, message: Message, channel: Channel) -> None:
    if message.file:
        file: File  = message.file
        file_id = file.media.id

        # Check if file_id already exists in database
        cursor.execute('SELECT file_id FROM media_items WHERE file_id = ?', (file_id,))
        if cursor.fetchone():
            print(f"Skipping download for existing file_id: {file_id}")
            return

        file_path = await download_media(client, message)
        if file_path:
            file_name = os.path.basename(file_path)

            if message.video or file_name.lower().endswith('.mp4'):
                media_type = 'video'
            elif message.gif:
                media_type = 'gif'
            elif message.photo:
                media_type = 'photo'
            elif message.document:
                mime_type = message.document.mime_type
                media_type = mime_type.split('/')[-1] if 'image/' in mime_type else 'document'
            else:
                media_type = 'unknown'

            cursor.execute('''
            INSERT OR REPLACE INTO media_items
            (file_id, date, channel, text, type, file_name, file_size, url)
            VALUES (?, ?, ?, ?, ?, ?, ?, ?)
            ''', (
                file_id,
                message.date,
                channel.title,
                message.text,
                media_type,
                file_name,
                message.file.size,
                f'/media/{file_name}'
            ))
            conn.commit()
            print(f"Processed {media_type}: {file_id}")
    elif message.web_preview:
        print(f"Skipping web preview: {message.id}")
    else:
        print(f"No media found: {message.id}")



async def main():
    chat_folders: DialogFilters = await client(functions.messages.GetDialogFiltersRequest())
    media_folder = next((folder for folder in chat_folders.filters if hasattr(folder, 'title') and folder.title == 'MediaView'), None)

    if not media_folder:
        print("MediaView folder not found")
        return

    target_channels = await asyncio.gather(*[client.get_entity(peer) for peer in media_folder.include_peers])

    for channel in tqdm(target_channels):
        print(f"Processing channel: {channel.title}")
        async for message in client.iter_messages(channel, limit=10):  # Adjust limit as needed
            await process_message(client, message, channel)

    print("Processing complete")

# Run the main function
await main()

# %%
client.disconnect()
conn.close()

# %%
"""
import sqlite3
import os

DB_PATH = './GOTTH/goth.db'
MEDIA_PATH = './static/media/'

def fix_mp4_entries():
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()

    # Get all entries
    cursor.execute('SELECT id, file_name, type FROM media_items')
    entries = cursor.fetchall()

    updated_count = 0

    for entry_id, file_name, current_type in entries:
        if file_name.lower().endswith('.mp4') and current_type != 'video':
            # Update the entry
            cursor.execute('UPDATE media_items SET type = ? WHERE id = ?', ('video', entry_id))
            updated_count += 1
            print(f"Updated entry {entry_id}: {file_name} from {current_type} to video")

        # Check if the file exists and has the correct extension
        file_path = os.path.join(MEDIA_PATH, file_name)
        if os.path.exists(file_path):
            _, file_extension = os.path.splitext(file_path)
            if file_extension.lower() != '.mp4' and current_type == 'video':
                new_file_name = f"{os.path.splitext(file_name)[0]}.mp4"
                new_file_path = os.path.join(MEDIA_PATH, new_file_name)
                os.rename(file_path, new_file_path)
                cursor.execute('UPDATE media_items SET file_name = ?, url = ? WHERE id = ?',
                               (new_file_name, f'/media/{new_file_name}', entry_id))
                updated_count += 1
                print(f"Renamed file and updated entry {entry_id}: {file_name} to {new_file_name}")

    conn.commit()
    conn.close()

    print(f"Updated {updated_count} entries")

fix_mp4_entries()

"""
